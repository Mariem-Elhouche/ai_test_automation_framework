# %%
# Installer Python 3.11
# !sudo apt-get update -y
# !sudo apt-get install python3.11 python3.11-distutils -y
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [89.0 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,599 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,990 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.1 MB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,292 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:17 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,193 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,862 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [61.6 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,863 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [86.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,601 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,142 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.7 kB]
# Fetched 41.5 MB in 5s (7,582 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.11-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# The following additional packages will be installed:
#   libpython3.11-minimal libpython3.11-stdlib python3.11-minimal
# Suggested packages:
#   python3.11-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.11-minimal libpython3.11-stdlib python3.11 python3.11-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 111 not upgraded.
# Need to get 5,261 kB of archives.
# After this operation, 21.1 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.11-minimal amd64 3.11.15-1+jammy1 [887 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.11-minimal amd64 3.11.15-1+jammy1 [2,353 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.11-stdlib amd64 3.11.15-1+jammy1 [1,927 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.11 amd64 3.11.15-1+jammy1 [94.3 kB]
# Fetched 5,261 kB in 12s (452 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.11-minimal:amd64.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../libpython3.11-minimal_3.11.15-1+jammy1_amd64.deb ...
# Unpacking libpython3.11-minimal:amd64 (3.11.15-1+jammy1) ...
# Selecting previously unselected package python3.11-minimal.
# Preparing to unpack .../python3.11-minimal_3.11.15-1+jammy1_amd64.deb ...
# Unpacking python3.11-minimal (3.11.15-1+jammy1) ...
# Selecting previously unselected package libpython3.11-stdlib:amd64.
# Preparing to unpack .../libpython3.11-stdlib_3.11.15-1+jammy1_amd64.deb ...
# Unpacking libpython3.11-stdlib:amd64 (3.11.15-1+jammy1) ...
# Selecting previously unselected package python3.11.
# Preparing to unpack .../python3.11_3.11.15-1+jammy1_amd64.deb ...
# Unpacking python3.11 (3.11.15-1+jammy1) ...
# Setting up libpython3.11-minimal:amd64 (3.11.15-1+jammy1) ...
# Setting up python3.11-minimal (3.11.15-1+jammy1) ...
# Setting up libpython3.11-stdlib:amd64 (3.11.15-1+jammy1) ...
# Setting up python3.11 (3.11.15-1+jammy1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !python3.11 --version
# Out:
# Python 3.11.15

# %%
# !pip install -q torch==2.7.1+cu118 torchvision==0.22.1+cu118 torchaudio==2.7.1+cu118 --index-url https://download.pytorch.org/whl/cu118
# !pip install -q transformers accelerate scipy flask pyngrok
# !pip install -q bitsandbytes==0.46.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 76.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 55.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 88.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.2/905.2 MB 961.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 10.8 MB/s eta 0:00:00

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.7.1+cu118
# True

# %%
# Check what's already installed — Colab ships with torch
import torch
import sys
import subprocess

print(torch.__version__)
print(torch.cuda.is_available())

# Only install the other dependencies
subprocess.run([sys.executable, "-m", "pip", "install", "-q",
    "transformers==4.46.3",
    "accelerate==1.2.1",
    "bitsandbytes==0.46.1",
    "scipy==1.13.1",
    "flask==3.1.0",
    "pyngrok==7.2.1",
    "sentencepiece==0.2.0",
    "protobuf==5.29.2",
], check=True)
# Out:
# 2.7.1+cu118
# True
# CompletedProcess(args=['/usr/bin/python3', '-m', 'pip', 'install', '-q', 'transformers==4.46.3', 'accelerate==1.2.1', 'bitsandbytes==0.46.1', 'scipy==1.13.1', 'flask==3.1.0', 'pyngrok==7.2.1', 'sentencepiece==0.2.0', 'protobuf==5.29.2'], returncode=0)

# %%
from google.colab import userdata
import os

# Méthode 1: Utiliser Colab Secrets
# Allez dans Settings > Secrets > Add new secret
# Nom: HF_TOKEN, Valeur: votre token HuggingFace

try:
    HF_TOKEN = userdata.get('HF_TOKEN')
    print("✅ Token HuggingFace chargé depuis Colab Secrets")
except:
    # Méthode 2: Token manuel (moins sécurisé)
    HF_TOKEN = "+++++++++++++"  # Remplacez par votre token
    print("⚠️  Token manuel utilisé ")

os.environ['HF_TOKEN'] = HF_TOKEN
# Out:
# ✅ Token HuggingFace chargé depuis Colab Secrets

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# Configuration de quantization 4-bit pour économiser la mémoire
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

MODEL_ID = "mistralai/Mistral-7B-Instruct-v0.3"

print("🔄 Chargement du tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(
    MODEL_ID,
    token=HF_TOKEN
)

print("🔄 Chargement du modèle Mistral-7B-Instruct (4-bit quantization)...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    quantization_config=bnb_config,
    device_map="auto",
    token=HF_TOKEN,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True
)

print("✅ Modèle chargé avec succès!")
print(f"📊 Mémoire GPU utilisée: {torch.cuda.memory_allocated()/1024**3:.2f} GB")
# Out:
# 🔄 Chargement du tokenizer...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# 🔄 Chargement du modèle Mistral-7B-Instruct (4-bit quantization)...
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ✅ Modèle chargé avec succès!
# 📊 Mémoire GPU utilisée: 3.85 GB

# %%
def create_bdd_prompt(user_story: str) -> str:

    system_instruction = """You are an expert QA Automation Engineer specialized in Behavior-Driven Development (BDD).
Your task is to generate comprehensive Gherkin feature files from user stories.

STRICT GHERKIN SYNTAX RULES:

1. TAGS:
   - Add ONE global feature tag on the line before Feature: (e.g. @login, @checkout, @authentication)
   - Each scenario must have EXACTLY TWO tags on the same line STRICTLY BEFORE the Scenario keyword:
     * First tag: a unique test case ID in format @TC_FEATURENAME_001, @TC_FEATURENAME_002, etc.
     * Second tag: one category tag (e.g. @smoke, @positive, @negative, @security, @validation, @edge-case)
   - THE RULE IS: @tags always come BEFORE the Scenario keyword, never after, never between.

2. BACKGROUND:
   - Use Background ONLY if the same Given steps repeat in ALL scenarios
   - Background MUST be placed immediately after the Feature description, before any Scenario
   - If not all scenarios share the same preconditions, do NOT use Background

3. FEATURE DESCRIPTION:
   - Feature description MUST be a single short sentence describing the functionality
   - NEVER write "As a... I want to... So that..." inside the Feature block

4. USER STORY SCOPE:
   - Generate scenarios STRICTLY based on the acceptance criteria.
   - Only generate flows explicitly described in the acceptance criteria.
   - If the acceptance criteria specify that only valid credentials are handled, do NOT generate invalid credential scenarios.
   - Do NOT generate logout scenarios unless logout is explicitly mentioned.
   - Do NOT invent new business rules or flows.

5. FLOW CONSOLIDATION:
   - Combine all steps of a main positive flow into a SINGLE scenario.
   - Do NOT fragment the flow into multiple scenarios for each page or action.
   - Include optional steps (like "Rester connecté ?") only if mentioned in the acceptance criteria, integrated in the same scenario.

6. STEP ATOMICITY:
   - Each step must represent ONE user action or ONE system outcome.
   - Do NOT combine multiple actions in a single step.

7. TERMINOLOGY AND ASCII:
   - Use plain ASCII characters only — NO unicode escapes.
   - Use "page" for web navigation (login page, password page, dashboard page).
   - Test data (emails, passwords, accounts) should be referenced externally (e.g., "valid email") and not hard-coded.

8. USER BEHAVIOR VS TEST AUTOMATION:
   - Steps must describe USER actions and SYSTEM responses only.
   - NEVER describe automation scripts, Selenium actions, or internal test implementation.

9. PAGE NAVIGATION:
   - Clearly indicate when a user action leads to page redirection.
   - Use the pattern: USER ACTION → PAGE REDIRECTION
   - Example: When the user submits a valid email → Then the user is redirected to the password page

10. SCENARIO TYPES:
    - Generate ONLY functional business scenarios (user-facing behaviors)
    - Generate positive scenarios for all main success flows
    - Include boundary condition scenarios when relevant (e.g. empty fields)
    - Use Scenario Outline only if multiple input combinations are implied

11. GHERKIN QUALITY:
    - Use proper Gherkin keywords only: Feature, Background, Scenario, Scenario Outline, Given, When, Then, And, But, Examples
    - Given: initial context/state
    - When: action performed by the user
    - Then: expected outcome
    - And/But: continues the previous keyword — never start a step block with And or But
    - Use clear, concise, actionable language
    - Avoid redundant wording

12. OUTPUT:
    - Output ONLY valid Gherkin content
    - Do NOT add comments, explanations, or any text outside the Gherkin block
    - Your response must start directly with the global @tag then Feature

13. LANGUAGE RULE:
   - Gherkin keywords MUST remain in English: Feature, Background, Scenario, Scenario Outline, Given, When, Then, And, But, Examples
   - Step descriptions MUST be written in French
   - Example:
     Given l'utilisateur est sur la page de connexion
     When l'utilisateur saisit un email valide
     Then l'utilisateur est redirigé vers le tableau de bord:"""

    user_content = f"""Generate a complete Gherkin feature file for the following user story:

USER STORY:
{user_story}

IMPORTANT REMINDERS:
- Global @tag goes on the line BEFORE Feature:
- Scenario tags go on the line BEFORE the Scenario keyword — NEVER after, NEVER between Scenario and steps
- Each scenario has EXACTLY two tags: @TC_FEATURENAME_XXX and one category tag
- Combine all main positive steps in a single scenario
- Do not fragment multi-step flows into multiple scenarios
- Use one action per step
- Only generate flows described in the acceptance criteria
- Use "page" terminology for web navigation
- Test data should be referenced externally, not hard-coded
- Output only valid Gherkin, nothing else
- Gherkin keywords must remain in English
- Step descriptions must be written in French"""

    prompt = f"""<s>[INST] {system_instruction}

{user_content} [/INST]"""

    return prompt

# %%
from flask import Flask, request, jsonify, send_file
from pyngrok import ngrok
from google.colab import userdata
import threading
import time
import os
import torch  # si n&#233;cessaire
import random
import string

app = Flask(__name__)

# R&#233;cup&#233;ration du token depuis Colab Secrets
try:
    NGROK_TOKEN = userdata.get('ngrok-token')
    ngrok.set_auth_token(NGROK_TOKEN)
    print("✅ Token ngrok chargé avec succes")
except Exception as e:
    print(f"⚠️ Erreur lors du chargement du token ngrok: {e}")

MODEL_ID = "feature-generator-v1"

def generate_feature_file(user_story):
    # Votre logique de g&#233;n&#233;ration
    return "Feature: ..."

def save_feature_file(content, user_story, filename):
    os.makedirs("/content/generated_features", exist_ok=True)
    if filename is None:
        # G&#233;n&#233;rer un nom &#224; partir de la user story
        filename = "generated.feature"
    filepath = os.path.join("/content/generated_features", filename)
    with open(filepath, "w") as f:
        f.write(content)
    return filepath

@app.route('/health', methods=['GET'])
def health():
    return jsonify({
        "status": "healthy",
        "model": MODEL_ID,
        "gpu_memory_allocated_gb": f"{torch.cuda.memory_allocated()/1024**3:.2f}" if torch.cuda.is_available() else "N/A"
    }), 200

@app.route('/generate', methods=['POST'])
def generate():
    try:
        data = request.get_json()
        if not data or 'user_story' not in data:
            return jsonify({"status": "error", "message": "Missing 'user_story'"}), 400
        user_story = data['user_story']
        filename = data.get('filename')
        print(f"὎8 Requ&#234;te re&#231;ue: {user_story[:100]}...")
        feature_content = generate_feature_file(user_story)
        filepath = save_feature_file(feature_content, user_story, filename)
        return jsonify({
            "status": "success",
            "content": feature_content,
            "filepath": filepath,
            "filename": os.path.basename(filepath)
        }), 200
    except Exception as e:
        print(f"❌ Erreur: {str(e)}")
        return jsonify({"status": "error", "message": str(e)}), 500

@app.route('/download/<filename>', methods=['GET'])
def download(filename):
    try:
        filepath = os.path.join("/content/generated_features", filename)
        if os.path.exists(filepath):
            return send_file(filepath, as_attachment=True)
        else:
            return jsonify({"status": "error", "message": "File not found"}), 404
    except Exception as e:
        return jsonify({"status": "error", "message": str(e)}), 500

def run_flask():
    app.run(port=5001, debug=False, use_reloader=False)

def setup_ngrok():
    try:
        # Fermer les &#233;ventuels tunnels de cette instance
        ngrok.kill()
        # G&#233;n&#233;rer un nom de tunnel unique pour &#233;viter le conflit
        tunnel_name = "feature-gen-" + ''.join(random.choices(string.ascii_lowercase + string.digits, k=8))
        public_url = ngrok.connect(5001, name=tunnel_name, bind_tls=True)
        print("\n" + "="*60)
        print("ἱ0 SERVEUR API D&#233;MARR&#233;")
        print("="*60)
        print(f"ὀD URL Locale:   http://localhost:5001")
        print(f"ἰD URL Publique: {public_url}")
        print("="*60)
        print("\nὍA ENDPOINTS DISPONIBLES:")
        print(f"  GET  {public_url}/health")
        print(f"  POST {public_url}/generate")
        print(f"  GET  {public_url}/download/<filename>")
        print("\nὊ1 Exemple de requ&#234;te curl:")
        print(f'''curl -X POST {public_url}/generate \\''')
        print('''  -H "Content-Type: application/json" \\''')
        print('''  -d '{"user_story": "As a user I want to..."}'\n''')
        print("="*60)
        return public_url
    except Exception as e:
        print(f"⚠️ Ngrok non disponible: {e}")
        print("ὀD Serveur accessible uniquement localement sur http://localhost:5001")
        return None

# D&#233;marrer le serveur dans un thread
print("Ὠ0 D&#233;marrage du serveur Flask sur le port 5001...")
flask_thread = threading.Thread(target=run_flask, daemon=True)
flask_thread.start()

# Attendre que Flask d&#233;marre
time.sleep(2)
public_url = setup_ngrok()

print("\n✅ Serveur pr&#233;t &#224; recevoir des requ&#234;tes!")
# Out:
# 🚀 Démarrage du serveur Flask sur le port 5001...
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# INFO:werkzeug:Press CTRL+C to quit
# ============================================================
# 🌐 SERVEUR API DÉMARRÉ
# ============================================================
# 📍 URL Locale:   http://localhost:5001
# 🌍 URL Publique: NgrokTunnel: "https://epigastric-troy-calculating.ngrok-free.dev" -> "http://localhost:5001"
# ============================================================
#
# 📚 ENDPOINTS DISPONIBLES:
#   GET  NgrokTunnel: "https://epigastric-troy-calculating.ngrok-free.dev" -> "http://localhost:5001"/health
#   POST NgrokTunnel: "https://epigastric-troy-calculating.ngrok-free.dev" -> "http://localhost:5001"/generate
#   GET  NgrokTunnel: "https://epigastric-troy-calculating.ngrok-free.dev" -> "http://localhost:5001"/download/<filename>
#
# 💡 Exemple de requête curl:
# curl -X POST NgrokTunnel: "https://epigastric-troy-calculating.ngrok-free.dev" -> "http://localhost:5001"/generate \
#   -H "Content-Type: application/json" \
#   -d '{"user_story": "As a user I want to..."}'
#
# ============================================================
#
# ✅ Serveur prêt à recevoir des requêtes!

# %%
import os
import re
import torch
from datetime import datetime

# ==========================================================
# 1️⃣ Génération du fichier Gherkin
# ==========================================================

def generate_feature_file(user_story: str, max_new_tokens: int = 2048) -> str:
    """
    Génère un fichier .feature Gherkin à partir d'une user story.
    """
    prompt = create_bdd_prompt(user_story)

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to(model.device)

    # ✅ Mesurer la longueur du prompt AVANT génération
    input_length = inputs["input_ids"].shape[1]

    print("🤖 Génération en cours...")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.7,
            top_p=0.9,
            top_k=50,
            do_sample=True,
            repetition_penalty=1.2,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id
        )

    # ✅ Décoder UNIQUEMENT les tokens générés (sans le prompt)
    generated_tokens = outputs[0][input_length:]
    generated_text = tokenizer.decode(generated_tokens, skip_special_tokens=True).strip()

    return clean_feature_content(generated_text)


# ==========================================================
# 2️⃣ Nettoyage du contenu — VERSION UNIQUE ET CORRECTE
# ==========================================================

def clean_feature_content(content: str) -> str:
    """Nettoie le contenu généré — extrait uniquement le bloc Gherkin valide."""

    if not content:
        return ""

    # Supprimer les balises markdown
    content = re.sub(r'```gherkin|```', '', content)

    # ✅ Couper tout ce qui précède Feature:
    match = re.search(r'(?m)^Feature:', content)
    if match:
        content = content[match.start():]
    else:
        return ""

    # ✅ Stopper ligne par ligne dès qu'on détecte du texte parasite
    valid_gherkin_lines = []
    for line in content.split('\n'):
        stripped = line.strip()

        if any(re.match(pattern, stripped, re.IGNORECASE) for pattern in [
            r'Generate a complete',
            r'Generate the \.feature',
            r'USER STORY',
            r'IMPORTANT REMINDERS',
            r'STRICT GHERKIN',
            r'^RULES:',
            r'Output ONLY',
            r'Do NOT',
            r'CORRECT:',
            r'WRONG:',
            r'Note:',
            r'In this feature',
            r'This feature file covers',
            r'\[INST\]',
            r'\[/INST\]',
        ]):
            break

        valid_gherkin_lines.append(line.rstrip())

    return '\n'.join(valid_gherkin_lines).strip()


# ==========================================================
# 3️⃣ Génération du nom basé sur la User Story
# ==========================================================

def generate_clean_filename_from_story(user_story: str) -> str:
    """Génère un nom de fichier court et intelligent à partir d'une user story."""

    if not user_story or not isinstance(user_story, str):
        return "generated_feature.feature"

    text = user_story.strip().lower()
    if not text:
        return "generated_feature.feature"

    if "acceptance criteria" in text:
        text = text.split("acceptance criteria")[0]

    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()

    patterns = [
        r"i want to (.+)",
        r"i need to (.+)",
        r"the system should (.+)",
        r"user can (.+)",
    ]

    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            action = match.group(1).strip()
            if action:
                words = action.split()[:3]
                if words:
                    filename = "_".join(words) + ".feature"
                    return re.sub(r'[^\w\-_\.]', '_', filename)

    stop_words = {"as", "a", "an", "the", "to", "i", "that", "so", "can", "in", "on", "at"}
    words = text.split()
    filtered_words = [w for w in words if w not in stop_words and len(w) > 2]

    if len(filtered_words) >= 3:
        filename = "_".join(filtered_words[:3]) + ".feature"
        return re.sub(r'[^\w\-_\.]', '_', filename)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    return f"feature_{timestamp}.feature"


# ==========================================================
# 4️⃣ Sauvegarde du fichier
# ==========================================================

def save_feature_file(content: str, user_story: str, filename: str = None) -> str:
    """Sauvegarde le contenu généré dans un fichier .feature."""

    if not content or not isinstance(content, str):
        raise ValueError("Le contenu du fichier ne peut pas être vide")

    output_dir = "/content/generated_features"
    os.makedirs(output_dir, exist_ok=True)

    if filename is None:
        try:
            filename = generate_clean_filename_from_story(user_story)
        except Exception as e:
            print(f"⚠️  Erreur nom fichier: {e}")
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"feature_{timestamp}.feature"

    if not filename.endswith(".feature"):
        filename += ".feature"

    filename = re.sub(r'[<>:"/\\|?*]', '_', filename)
    filepath = os.path.join(output_dir, filename)

    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(content)

    print(f"✅ Fichier sauvegardé: {filepath}")
    return filepath


# ==========================================================
# 5️⃣ TEST
# ==========================================================

sample_story = """
As a backoffice administrator
I want to log in to the system with my credentials
So that I can access the admin dashboard securely

Acceptance Criteria:
- User can login with valid username and password
- Invalid credentials show error message
- Password field is masked
- After 3 failed attempts, account is locked for 15 minutes
"""

try:
    print("\n" + "="*60)
    print("🧪 TEST DE GÉNÉRATION")
    print("="*60)

    feature_content = generate_feature_file(sample_story)
    print("\n✅ Génération réussie")
    print("\n📄 Contenu généré:")
    print(feature_content)

    saved_path = save_feature_file(feature_content, sample_story)

    print("\n📂 Fichiers générés:")
    for f in os.listdir("/content/generated_features"):
        print(f"  - {f}")

except Exception as e:
    print(f"\n❌ Erreur: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ============================================================
# 🧪 TEST DE GÉNÉRATION
# ============================================================
# 🤖 Génération en cours...
#
# ✅ Génération réussie
#
# 📄 Contenu généré:
# Feature: Connexion au système pour les utilisateurs de bureau
#
# Scénario : Connecter avec des identifiants valides et accès à la plateforme
#   @TC_login_001 @positive
#   Quand l'administrateur entre sur la page de connexion
#   Et il renseigne son identifiant valide
#   Et il renseigne son mot de passe secret
#   Alors l'admin est autorisé à se connecter et est redirigé vers la plateforme de gestion du bureau
#
# Scénario : Identifiant ou mot de passe incorrecte -- Affichage d'un message d'erreur
#   @TC_login_002 @negative
#   Quand l'administrateur entre sur la page de connexion
#   Et il renseigne un identifiant incorrect
#   Ou il renseigne un mot de passe incorrect
#   Alors il reçoit une erreur en ligne indiquant qu'il y a eu une erreur lors de la tentative de connexion
#
# Scénario : Champs mots de passe cachés
#   @TC_login_003 @validation
#   Quand l'administrateur entre sur la page de connexion
#   Alors les champs Mot de passe sont masqués par des points de suspension (*)
#
# Scénario : Expiration après 3 essais infructueux -- Verrouillage compte
#   @TC_login_004 @edge-case
#   Quand l'administrateur effectue trois tentatives d'accès infructueuses consécutives
#   Alors son compte est verrouillé pendant 15 minutes
# ✅ Fichier sauvegardé: /content/generated_features/log_in_to.feature
#
# 📂 Fichiers générés:
#   - log_in_to.feature

# %% [markdown]
# **tester la cellule ci dessous ( meme role que celle au dessus )**

# %%
import os
import re
import torch
from datetime import datetime

# ==========================================================
# 1️⃣ Génération du fichier Gherkin
# ==========================================================

def generate_feature_file(user_story: str, max_new_tokens: int = 2048) -> str:
    """
    Génère un fichier .feature Gherkin à partir d'une user story.
    """
    prompt = create_bdd_prompt(user_story)

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to(model.device)

    # ✅ Mesurer la longueur du prompt AVANT génération
    input_length = inputs["input_ids"].shape[1]

    print("🤖 Génération en cours...")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.7,
            top_p=0.9,
            top_k=50,
            do_sample=True,
            repetition_penalty=1.2,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id
        )

    # ✅ Décoder UNIQUEMENT les tokens générés (sans le prompt)
    generated_tokens = outputs[0][input_length:]
    generated_text = tokenizer.decode(generated_tokens, skip_special_tokens=True).strip()

    # ✅ Remettre le @ forcé dans le prompt
    generated_text = "@" + generated_text

    return clean_feature_content(generated_text)


# ==========================================================
# 2️⃣ Nettoyage du contenu
# ==========================================================
def clean_feature_content(content: str) -> str:
    """Nettoie le contenu généré — extrait uniquement le bloc Gherkin valide et convertit en ASCII."""
    if not content:
        return ""

    # Supprimer les balises markdown
    content = re.sub(r'```gherkin|```', '', content)

    # Couper tout ce qui précède Feature:
    match = re.search(r'(?m)^Feature:', content)
    if match:
        content = content[match.start():]
    else:
        return ""

    valid_gherkin_lines = []
    for line in content.split('\n'):
        stripped = line.strip()

        if any(re.match(pattern, stripped, re.IGNORECASE) for pattern in [
            r'Generate a complete',
            r'Generate the \.feature',
            r'USER STORY',
            r'IMPORTANT REMINDERS',
            r'STRICT GHERKIN',
            r'^RULES:',
            r'Output ONLY',
            r'Do NOT',
            r'CORRECT:',
            r'WRONG:',
            r'Note:',
            r'In this feature',
            r'This feature file covers',
            r'\[INST\]',
            r'\[/INST\]',
        ]):
            break

        # ✅ Forcer ASCII simple
        line_ascii = line.encode('ascii', errors='ignore').decode('ascii')
        valid_gherkin_lines.append(line_ascii.rstrip())

    return '\n'.join(valid_gherkin_lines).strip()

# ==========================================================
# 3️⃣ Génération du nom basé sur la User Story
# ==========================================================

def generate_clean_filename_from_story(user_story: str) -> str:
    """Génère un nom de fichier court et intelligent à partir d'une user story."""

    if not user_story or not isinstance(user_story, str):
        return "generated_feature.feature"

    text = user_story.strip().lower()
    if not text:
        return "generated_feature.feature"

    if "acceptance criteria" in text:
        text = text.split("acceptance criteria")[0]

    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()

    patterns = [
        r"i want to (.+)",
        r"i need to (.+)",
        r"the system should (.+)",
        r"user can (.+)",
    ]

    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            action = match.group(1).strip()
            if action:
                words = action.split()[:3]
                if words:
                    filename = "_".join(words) + ".feature"
                    return re.sub(r'[^\w\-_\.]', '_', filename)

    stop_words = {"as", "a", "an", "the", "to", "i", "that", "so", "can", "in", "on", "at"}
    words = text.split()
    filtered_words = [w for w in words if w not in stop_words and len(w) > 2]

    if len(filtered_words) >= 3:
        filename = "_".join(filtered_words[:3]) + ".feature"
        return re.sub(r'[^\w\-_\.]', '_', filename)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    return f"feature_{timestamp}.feature"


# ==========================================================
# 4️⃣ Sauvegarde du fichier
# ==========================================================

def save_feature_file(content: str, user_story: str, filename: str = None) -> str:
    """Sauvegarde le contenu généré dans un fichier .feature."""

    if not content or not isinstance(content, str):
        raise ValueError("Le contenu du fichier ne peut pas être vide")

    output_dir = "/content/generated_features"
    os.makedirs(output_dir, exist_ok=True)

    if filename is None:
        try:
            filename = generate_clean_filename_from_story(user_story)
        except Exception as e:
            print(f"⚠️  Erreur nom fichier: {e}")
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"feature_{timestamp}.feature"

    if not filename.endswith(".feature"):
        filename += ".feature"

    filename = re.sub(r'[<>:"/\\|?*]', '_', filename)
    filepath = os.path.join(output_dir, filename)

    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(content)

    print(f"✅ Fichier sauvegardé: {filepath}")
    return filepath


# ==========================================================
# 5️⃣ TEST
# ==========================================================

sample_story = """
As a backoffice administrator
I want to log in to the system with my credentials
So that I can access the admin dashboard securely

Acceptance Criteria:
- User can login with valid username and password
- Invalid credentials show error message
- Password field is masked
- After 3 failed attempts, account is locked for 15 minutes
"""

try:
    print("\n" + "="*60)
    print("🧪 TEST DE GÉNÉRATION")
    print("="*60)

    feature_content = generate_feature_file(sample_story)
    print("\n✅ Génération réussie")
    print("\n📄 Contenu généré:")
    print(feature_content)

    saved_path = save_feature_file(feature_content, sample_story)

    print("\n📂 Fichiers générés:")
    for f in os.listdir("/content/generated_features"):
        print(f"  - {f}")

except Exception as e:
    print(f"\n❌ Erreur: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ============================================================
# 🧪 TEST DE GÉNÉRATION
# ============================================================
# 🤖 Génération en cours...
#
# ✅ Génération réussie
#
# 📄 Contenu généré:
# Feature: Se connecter en tant qu'administrateur du bureau
#
# Scnario : Connexion russie avec des informations d'identification valides
#   @TC_login_001 @positive
#   tat initial :
#       Les donnes d'identification sont correctes et mmorises
#
#       Une fois sur la page de connexion
#       Lorsque l'utilisateur saisit une adresse e-mail valide
#       Et lorsqu'il saisit un mot de passe valide
#       Alors l'utilisateur est redirig vers l'espace de travail de l'administrateur
#
# Scnario : Erreur lors de la tentative de connexion avec des informations incorrectes
#   @TC_login_002 @negative
#   tat initial :
#       Des erreurs ont t commises dans les informations d'identification
#
#       Une fois sur la page de connexion
#       Lorsque l'utilisateur saisit une adresse e-mail incorrecte
#       Et lorsqu'il saisit un mot de passe incorrect
#       Alors un message d'erreur s'affiche indiquant que les informations d'identification ne correspondent pas
#
# Scnario : Masquage du champ Mot de passe
#   @TC_login_003 @validation
#   tat initial :
#       Le champ Mot de passe est masqu par dfaut
#
#       Une fois sur la page de connexion
#       Quand l'utilisateur clique sur le champ Mot de passe
#       Alors il est possible de voir que le contenu est cach par des points de suspension
#
# Scnario : Verrouillage du compte aprs trois essais infructueux de connexion
#   @TC_login_004 @edge-case
#   tat initial :
#       Trois essais infructueux de connexion ont eu lieu
#
#       Une fois sur la page de connexion
#       Lorsque l'utilisateur entre une troisime fois des informations incorrectes
#       Alors son compte est verrouill pendant 15 minutes avant que l'on puisse tenter  nouveau de se connecter
# ✅ Fichier sauvegardé: /content/generated_features/log_in_to.feature
#
# 📂 Fichiers générés:
#   - log_in_to.feature

# %%
# !curl -X POST https://epigastric-troy-calculating.ngrok-free.dev/generate \
  -H "Content-Type: application/json" \
  -H "ngrok-skip-browser-warning: true" \
  -d "{\"user_story\": \"As a user I want to login with valid credentials\"}"
# Out:
# 📨 Requête reçue: As a user I want to login with valid credentials...
# 🤖 Génération en cours...
# INFO:werkzeug:127.0.0.1 - - [30/Apr/2026 09:36:35] "POST /generate HTTP/1.1" 200 -
# ✅ Fichier sauvegardé: /content/generated_features/login_with_valid.feature
# {"content":"Feature: Connexion avec des informations d'identification valides\n\nScnario : Connecter l'utilisateur avec des informations d'identification valides\n  @TC_CONNECTION_001 @positive\n  Quand l'utilisateur se rend  la page de connexion\n  Et l'utilisateur entre son adresse e-mail valide et mot de passe correct\n  Alors l'utilisateur est russi  s'identifier et est redirig vers le tableau de bord\n\nScnario : Ressayer une connection avec des informations d'identification incorrectes\n  @TC_CONNECTION_002 @negative\n  Quand l'utilisateur tente de s'identifier avec des informations incorrectes\n  Alors il reoit une erreur indiquant que les informations fournies sont incorrectes","filename":"login_with_valid.feature","filepath":"/content/generated_features/login_with_valid.feature","status":"success"}
